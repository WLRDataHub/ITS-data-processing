# %%
import sys
sys.path.append('../')

# %%
"""
# Description:  Converts the U.S. Department of Interior's National 
#               Fire Plan Operations and Reporting System (NFPORS) dataset 
#               into the Task Force standardized schema.  Dataset
#               is enriched with vegetation, ownership, county, WUI, 
#               Task Force Region, and year.
#               BLM and NPS current year treatments are inlcuded but past 
#               years treatments excluded and managed by seperate notebooks.
# Author: Spatial Informatics Group LLC
# Version: 1.0.0
# Date Created: Jan 24, 2024
"""
import os
import arcpy
import datetime
from scripts.utils import init_gdb, og_file_input
from scripts._3a_NFPORS import Model_NFPORS_poly, Model_NFPORS_point

workspace, scratch_workspace = init_gdb()
arcpy.env.overwriteOutput = True

date_id = datetime.datetime.now().strftime("%Y-%m-%d").replace('-','') # like 20221216

# INPUTS
# Will need to re-download NFPORS dataset each for each update from the below web service URL
# Check that NFPORS downloads correctly because the service is throttled to limit the number of downloadable features per call 
# https://usgs.nfpors.gov/arcgis/rest/services/nfpors_WM/MapServer/15

# BLM and NPS features are processed with a different notebook from their own feature services

# finds the latest version by date (like 20240124 (YYYMMDD))
#nfpors_poly = og_file_input(prefix = 'nfpors_fuels_treatments_', filetype = 'Polygon', gdb = os.path.join(workspace, "b_Originals"))
#input_original_polys = os.path.join(workspace,'b_Originals',nfpors_poly)



project_path = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
data2023_path = os.path.join(project_path, "2023")
#data2022_path = os.path.join(project_path, "2022")

nfpors_gdb = os.path.join(data2023_path, "NFPORS_2023", "NFPORS_2023_20240624_ServiceDownload.gdb")
#nfpors_gdb = os.path.join(data2022_path, "NFPORS_2022", "NFPORS_2022_20221110_20230717_fromCarlITSgdb.gdb")


input_original_polys = os.path.join(nfpors_gdb, "NFPORS_2023_20240619_Fuel_Treatment_Polygons_ServiceDownload")
#input_original_polys = os.path.join(nfpors_gdb, "nfpors_fuels_treatments_20230717b")
# Downloads and saves BIA and FWS current year project points to scratch gdb prior to being appended together in Model_NFPORS
query_CA = "statename='California'"

input_original_pts_BIA = os.path.join(nfpors_gdb, "NFPORS_2023_20240619_Current_FY_Treatments_BIA_ServiceDownload")
input_original_pts_FWS = os.path.join(nfpors_gdb, "NFPORS_2023_20240619_Current_FY_Treatments_FWS_ServiceDownload")


#bia_api = 'https://usgs.nfpors.gov/arcgis/rest/services/nfpors_WM/MapServer/1'
#bia_fs = arcpy.FeatureSet(bia_api, query_CA)
#input_original_pts_BIA = os.path.join(workspace,'b_Originals', f'NFPORSCurrentFYTreatmentsBIA_{date_id}')
#get_bia_pt = arcpy.CopyFeatures_management(bia_fs, input_original_pts_BIA)
#print("BIA current year points copied from rest service")

#fws_api = 'https://usgs.nfpors.gov/arcgis/rest/services/nfpors_WM/MapServer/5'
#fws_fs = arcpy.FeatureSet(fws_api, query_CA)
#input_original_pts_FWS = os.path.join(workspace,'b_Originals', f'NFPORSCurrentFYTreatmentsFWS_{date_id}')
#get_fws_pt = arcpy.CopyFeatures_management(fws_fs, input_original_pts_FWS)
#print("FWS current year points copied from rest service")
# Out:
# Start Time 2024-09-25 11:47:26.471413

# %%
# OUTPUTS
#output_pts_enriched = os.path.join(workspace, 'c_Enriched',f'nfpors_fuels_treatments_pts_enriched2022_{date_id}')
#output_polys_enriched = os.path.join(workspace,'c_Enriched',f'nfpors_fuels_treatments_polys_enriched2022_{date_id}')
output_pts_enriched = os.path.join(workspace, 'c_Enriched',f'nfpors_fuels_treatments_pts_enriched2023_{date_id}')
output_polys_enriched = os.path.join(workspace,'c_Enriched',f'nfpors_fuels_treatments_polys_enriched2023_{date_id}')

# %%
Model_NFPORS_poly(
    input_original_polys,
    output_polys_enriched, 
    output_pts_enriched
)
# Out:
# Performing Polygons Standardization
#    step 1/7 select by DOI agency (BIA, FWS)
# ========> ['OBJECTID', 'Shape', 'trt_unt_id', 'local_id', 'col_date', 'trt_status', 'col_meth', 'comments', 'gis_acres', 'pstatus', 'modifiedon', 'createdon', 'cent_lat', 'cent_lon', 'userid', 'st_abbr', 'cong_dist', 'cnty_fips', 'trt_nm', 'fy', 'plan_acc_ac', 'act_acc_ac', 'act_init_dt', 'act_comp_dt', 'nfporsfid', 'trt_id_db', 'type_name', 'cat_nm', 'trt_statnm', 'col_methnm', 'plan_int_dt', 'unit_id', 'agency', 'trt_id', 'created_by', 'edited_by', 'projectname', 'regionname', 'projectid', 'keypointarea', 'unitname', 'deptname', 'countyname', 'statename', 'regioncode', 'districtname', 'isbil', 'bilfunding', 'Shape_Length', 'Shape_Area']
#    step 2/7 select after 1995
#    step 3/7 select CA
#    step 4/7 repair geometry
#    step 5/7 rename and add fields
#       assigning domains
#    step 6/7 import attributes
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'Shape', 'trt_unt_id', 'local_id', 'col_date', 'trt_status', 'col_meth', 'comments', 'gis_acres', 'pstatus', 'modifiedon', 'createdon', 'cent_lat', 'cent_lon', 'userid', 'st_abbr', 'cong_dist', 'cnty_fips', 'trt_nm', 'fy', 'plan_acc_ac', 'act_acc_ac', 'act_init_dt', 'act_comp_dt', 'nfporsfid', 'trt_id_db', 'type_name', 'cat_nm', 'trt_statnm', 'col_methnm', 'plan_int_dt', 'unit_id', 'agency_', 'trt_id', 'created_by', 'edited_by', 'projectname', 'regionname', 'projectid', 'keypointarea', 'unitname', 'deptname', 'countyname', 'statename', 'regioncode', 'districtname', 'isbil', 'bilfunding', 'Shape_Length', 'Shape_Area', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#         field_list after: ['OBJECTID', 'Shape', 'projectid', 'Shape_Length', 'Shape_Area', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#    Standardization Complete
#      standardized has 661 records
#    Executing Polygon Enrichments...
#      Polygon Enrichment Start Time 2024-09-25 11:47:26.477925
#      Calculating Broad Vegetation Type...
#        enrich step 1/32 summarize veg within polygons
#
#
# ==========> Number of features in Veg_Layer: 3736147
# -- enrich_in
# ==========> Number of features in enrich_in: 661
#
#
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#
# ---------- group table -------------
#         Fields: ['OBJECTID', 'Join_ID', 'WHR13NAME', 'sum_Area_ACRES', 'Polygon_Count']
#        enrich step 2/32 summarize attributes
#       OBJECTID  Join_ID          WHR13NAME  sum_Area_ACRES  Polygon_Count
# 0            1        1            Wetland      148.274813              1
# 1            2        2        Agriculture        0.725276              1
# 2            3        2  Hardwood Woodland        0.345857              1
# 3            4        2         Herbaceous        0.486454              2
# 4            5        2            Wetland       36.563732              1
# ...        ...      ...                ...             ...            ...
# 2045      2046      661  Hardwood Woodland       11.813717             12
# 2046      2047      661         Herbaceous        8.171090              9
# 2047      2048      661              Shrub        5.299561             20
# 2048      2049      661              Water        0.000358              1
# 2049      2050      661            Wetland        2.310180              8
#
# [2050 rows x 5 columns]
#
# ---------- grouped_df -------------
#      Join_ID  MAX_Sum_Area_ACRES  OBJECTID
# 0          1          148.274813         1
# 1          2           36.563732         2
# 2          3           17.021283         3
# 3          4           38.515147         4
# 4          5            5.624384         5
# ..       ...                 ...       ...
# 638      657            7.341732       639
# 639      658            4.651120       640
# 640      659            3.802817       641
# 641      660            4.420101       642
# 642      661           11.813717       643
#
# [643 rows x 3 columns]
#        enrich step 3/32 add join
#
# ----------- join_1 --------------
#         Fields: ['WHR13NAME_Summary_SummarizeAttributes.OBJECTID', 'WHR13NAME_Summary_SummarizeAttributes.Join_ID', 'WHR13NAME_Summary_SummarizeAttributes.MAX_Sum_Area_ACRES', 'WHR13NAME_Summary.OBJECTID', 'WHR13NAME_Summary.Join_ID', 'WHR13NAME_Summary.WHR13NAME', 'WHR13NAME_Summary.sum_Area_ACRES', 'WHR13NAME_Summary.Polygon_Count']
#          join_1 has 1175 records
#        enrich step 4/32 convert table to table
#
# ----------- sum_table --------------
#         Fields: ['OBJECTID_1', 'Join_ID', 'MAX_Sum_Area_ACRES', 'OBJECTID', 'Join_ID_1', 'WHR13NAME', 'sum_Area_ACRES', 'Polygon_Count']
#        enrich step 5/32 delete identical
#          step has 643 records
#
# ----------- veg_sum --------------
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#          veg_sum has 661 records
#
# ----------- delete_identical_1 --------------
#         Fields: ['OBJECTID_1', 'Join_ID', 'MAX_Sum_Area_ACRES', 'OBJECTID', 'Join_ID_1', 'WHR13NAME', 'sum_Area_ACRES', 'Polygon_Count']
#          delete_identical_1 has 643 records
#        enrich step 6/32 add join
#
# ----------- join_2 --------------
#         Fields: ['Veg_Summarized_Polygons.OBJECTID', 'Veg_Summarized_Polygons.Shape', 'Veg_Summarized_Polygons.projectid', 'Veg_Summarized_Polygons.PROJECTID_USER', 'Veg_Summarized_Polygons.AGENCY', 'Veg_Summarized_Polygons.ORG_ADMIN_p', 'Veg_Summarized_Polygons.PROJECT_CONTACT', 'Veg_Summarized_Polygons.PROJECT_EMAIL', 'Veg_Summarized_Polygons.ADMINISTERING_ORG', 'Veg_Summarized_Polygons.PROJECT_NAME', 'Veg_Summarized_Polygons.PROJECT_STATUS', 'Veg_Summarized_Polygons.PROJECT_START', 'Veg_Summarized_Polygons.PROJECT_END', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_SOURCE', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_ORG', 'Veg_Summarized_Polygons.IMPLEMENTING_ORG', 'Veg_Summarized_Polygons.LATITUDE', 'Veg_Summarized_Polygons.LONGITUDE', 'Veg_Summarized_Polygons.BatchID_p', 'Veg_Summarized_Polygons.Val_Status_p', 'Veg_Summarized_Polygons.Val_MSG_p', 'Veg_Summarized_Polygons.Val_RunDate_p', 'Veg_Summarized_Polygons.Review_Status_p', 'Veg_Summarized_Polygons.Review_MSG_p', 'Veg_Summarized_Polygons.Review_RunDate_p', 'Veg_Summarized_Polygons.Dataload_Status_p', 'Veg_Summarized_Polygons.Dataload_Msg_p', 'Veg_Summarized_Polygons.TRMTID_USER', 'Veg_Summarized_Polygons.PROJECTNAME_', 'Veg_Summarized_Polygons.ORG_ADMIN_t', 'Veg_Summarized_Polygons.PRIMARY_OWNERSHIP_GROUP', 'Veg_Summarized_Polygons.PRIMARY_OBJECTIVE', 'Veg_Summarized_Polygons.SECONDARY_OBJECTIVE', 'Veg_Summarized_Polygons.TERTIARY_OBJECTIVE', 'Veg_Summarized_Polygons.TREATMENT_STATUS', 'Veg_Summarized_Polygons.COUNTY', 'Veg_Summarized_Polygons.IN_WUI', 'Veg_Summarized_Polygons.REGION', 'Veg_Summarized_Polygons.TREATMENT_AREA', 'Veg_Summarized_Polygons.TREATMENT_START', 'Veg_Summarized_Polygons.TREATMENT_END', 'Veg_Summarized_Polygons.RETREATMENT_DATE_EST', 'Veg_Summarized_Polygons.TREATMENT_NAME', 'Veg_Summarized_Polygons.BatchID', 'Veg_Summarized_Polygons.Val_Status_t', 'Veg_Summarized_Polygons.Val_MSG_t', 'Veg_Summarized_Polygons.Val_RunDate_t', 'Veg_Summarized_Polygons.Review_Status_t', 'Veg_Summarized_Polygons.Review_Msg_t', 'Veg_Summarized_Polygons.Review_RunDate_t', 'Veg_Summarized_Polygons.Dataload_Status_t', 'Veg_Summarized_Polygons.Dataload_Msg_t', 'Veg_Summarized_Polygons.ACTIVID_USER', 'Veg_Summarized_Polygons.TREATMENTID_', 'Veg_Summarized_Polygons.ORG_ADMIN_a', 'Veg_Summarized_Polygons.ACTIVITY_DESCRIPTION', 'Veg_Summarized_Polygons.ACTIVITY_CAT', 'Veg_Summarized_Polygons.BROAD_VEGETATION_TYPE', 'Veg_Summarized_Polygons.BVT_USERD', 'Veg_Summarized_Polygons.ACTIVITY_STATUS', 'Veg_Summarized_Polygons.ACTIVITY_QUANTITY', 'Veg_Summarized_Polygons.ACTIVITY_UOM', 'Veg_Summarized_Polygons.ACTIVITY_START', 'Veg_Summarized_Polygons.ACTIVITY_END', 'Veg_Summarized_Polygons.ADMIN_ORG_NAME', 'Veg_Summarized_Polygons.IMPLEM_ORG_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.TERTIARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.TERTIARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.ACTIVITY_PRCT', 'Veg_Summarized_Polygons.RESIDUE_FATE', 'Veg_Summarized_Polygons.RESIDUE_FATE_QUANTITY', 'Veg_Summarized_Polygons.RESIDUE_FATE_UNITS', 'Veg_Summarized_Polygons.ACTIVITY_NAME', 'Veg_Summarized_Polygons.VAL_STATUS_a', 'Veg_Summarized_Polygons.VAL_MSG_a', 'Veg_Summarized_Polygons.VAL_RUNDATE_a', 'Veg_Summarized_Polygons.REVIEW_STATUS_a', 'Veg_Summarized_Polygons.REVIEW_MSG_a', 'Veg_Summarized_Polygons.REVIEW_RUNDATE_a', 'Veg_Summarized_Polygons.DATALOAD_STATUS_a', 'Veg_Summarized_Polygons.DATALOAD_MSG_a', 'Veg_Summarized_Polygons.Source', 'Veg_Summarized_Polygons.Year', 'Veg_Summarized_Polygons.Year_txt', 'Veg_Summarized_Polygons.Act_Code', 'Veg_Summarized_Polygons.Crosswalk', 'Veg_Summarized_Polygons.Federal_FY', 'Veg_Summarized_Polygons.State_FY', 'Veg_Summarized_Polygons.TRMT_GEOM', 'Veg_Summarized_Polygons.COUNTS_TO_MAS', 'Veg_Summarized_Polygons.Shape_Length', 'Veg_Summarized_Polygons.Shape_Area', 'Veg_Summa ...
#          join_2 has 661 records
#        enrich step 7/32 select layer by attribute
#
# ----------- select_1 --------------
#         Fields: ['Veg_Summarized_Polygons.OBJECTID', 'Veg_Summarized_Polygons.Shape', 'Veg_Summarized_Polygons.projectid', 'Veg_Summarized_Polygons.PROJECTID_USER', 'Veg_Summarized_Polygons.AGENCY', 'Veg_Summarized_Polygons.ORG_ADMIN_p', 'Veg_Summarized_Polygons.PROJECT_CONTACT', 'Veg_Summarized_Polygons.PROJECT_EMAIL', 'Veg_Summarized_Polygons.ADMINISTERING_ORG', 'Veg_Summarized_Polygons.PROJECT_NAME', 'Veg_Summarized_Polygons.PROJECT_STATUS', 'Veg_Summarized_Polygons.PROJECT_START', 'Veg_Summarized_Polygons.PROJECT_END', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_SOURCE', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_ORG', 'Veg_Summarized_Polygons.IMPLEMENTING_ORG', 'Veg_Summarized_Polygons.LATITUDE', 'Veg_Summarized_Polygons.LONGITUDE', 'Veg_Summarized_Polygons.BatchID_p', 'Veg_Summarized_Polygons.Val_Status_p', 'Veg_Summarized_Polygons.Val_MSG_p', 'Veg_Summarized_Polygons.Val_RunDate_p', 'Veg_Summarized_Polygons.Review_Status_p', 'Veg_Summarized_Polygons.Review_MSG_p', 'Veg_Summarized_Polygons.Review_RunDate_p', 'Veg_Summarized_Polygons.Dataload_Status_p', 'Veg_Summarized_Polygons.Dataload_Msg_p', 'Veg_Summarized_Polygons.TRMTID_USER', 'Veg_Summarized_Polygons.PROJECTNAME_', 'Veg_Summarized_Polygons.ORG_ADMIN_t', 'Veg_Summarized_Polygons.PRIMARY_OWNERSHIP_GROUP', 'Veg_Summarized_Polygons.PRIMARY_OBJECTIVE', 'Veg_Summarized_Polygons.SECONDARY_OBJECTIVE', 'Veg_Summarized_Polygons.TERTIARY_OBJECTIVE', 'Veg_Summarized_Polygons.TREATMENT_STATUS', 'Veg_Summarized_Polygons.COUNTY', 'Veg_Summarized_Polygons.IN_WUI', 'Veg_Summarized_Polygons.REGION', 'Veg_Summarized_Polygons.TREATMENT_AREA', 'Veg_Summarized_Polygons.TREATMENT_START', 'Veg_Summarized_Polygons.TREATMENT_END', 'Veg_Summarized_Polygons.RETREATMENT_DATE_EST', 'Veg_Summarized_Polygons.TREATMENT_NAME', 'Veg_Summarized_Polygons.BatchID', 'Veg_Summarized_Polygons.Val_Status_t', 'Veg_Summarized_Polygons.Val_MSG_t', 'Veg_Summarized_Polygons.Val_RunDate_t', 'Veg_Summarized_Polygons.Review_Status_t', 'Veg_Summarized_Polygons.Review_Msg_t', 'Veg_Summarized_Polygons.Review_RunDate_t', 'Veg_Summarized_Polygons.Dataload_Status_t', 'Veg_Summarized_Polygons.Dataload_Msg_t', 'Veg_Summarized_Polygons.ACTIVID_USER', 'Veg_Summarized_Polygons.TREATMENTID_', 'Veg_Summarized_Polygons.ORG_ADMIN_a', 'Veg_Summarized_Polygons.ACTIVITY_DESCRIPTION', 'Veg_Summarized_Polygons.ACTIVITY_CAT', 'Veg_Summarized_Polygons.BROAD_VEGETATION_TYPE', 'Veg_Summarized_Polygons.BVT_USERD', 'Veg_Summarized_Polygons.ACTIVITY_STATUS', 'Veg_Summarized_Polygons.ACTIVITY_QUANTITY', 'Veg_Summarized_Polygons.ACTIVITY_UOM', 'Veg_Summarized_Polygons.ACTIVITY_START', 'Veg_Summarized_Polygons.ACTIVITY_END', 'Veg_Summarized_Polygons.ADMIN_ORG_NAME', 'Veg_Summarized_Polygons.IMPLEM_ORG_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.TERTIARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.TERTIARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.ACTIVITY_PRCT', 'Veg_Summarized_Polygons.RESIDUE_FATE', 'Veg_Summarized_Polygons.RESIDUE_FATE_QUANTITY', 'Veg_Summarized_Polygons.RESIDUE_FATE_UNITS', 'Veg_Summarized_Polygons.ACTIVITY_NAME', 'Veg_Summarized_Polygons.VAL_STATUS_a', 'Veg_Summarized_Polygons.VAL_MSG_a', 'Veg_Summarized_Polygons.VAL_RUNDATE_a', 'Veg_Summarized_Polygons.REVIEW_STATUS_a', 'Veg_Summarized_Polygons.REVIEW_MSG_a', 'Veg_Summarized_Polygons.REVIEW_RUNDATE_a', 'Veg_Summarized_Polygons.DATALOAD_STATUS_a', 'Veg_Summarized_Polygons.DATALOAD_MSG_a', 'Veg_Summarized_Polygons.Source', 'Veg_Summarized_Polygons.Year', 'Veg_Summarized_Polygons.Year_txt', 'Veg_Summarized_Polygons.Act_Code', 'Veg_Summarized_Polygons.Crosswalk', 'Veg_Summarized_Polygons.Federal_FY', 'Veg_Summarized_Polygons.State_FY', 'Veg_Summarized_Polygons.TRMT_GEOM', 'Veg_Summarized_Polygons.COUNTS_TO_MAS', 'Veg_Summarized_Polygons.Shape_Length', 'Veg_Summarized_Polygons.Shape_Area', 'Veg_Summa ...
#          select_1 has 0 records
#          select_1 has 0 records
#        enrich step 8/32 calculate user defined veg field yes
#        enrich step 9/32 select layer by attribute
#        enrich step 10/32 calculate veg domain code
#        enrich step 11/32 calculate user defined veg field no
#        enrich step 12/32 remove join
#          step has 661 records
#
# ----------- remove_join_1 --------------
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#      Calculating WUI...
#        enrich step 13/32 select layer by attribute
#        enrich step 14/32 select layer by WUI location
#        enrich step 15/32 calculate WUI yes
#
# ----------- calc_field_4 --------------
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#        enrich step 16/32 select layer by attribute
#        enrich step 17/32 calculate WUI no
#        enrich step 18/32 clear selection
#
# ----------- select_7 --------------
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#        enrich step 19/32 feature to point
#
# ----------- to_points --------------
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID', 'ORIG_FID']
#      Calculating Ownership, Counties, and Regions...
#        enrich step 20/32 spatial join ownership
#        enrich step 21/32 spatial join veg
#        enrich step 22/32 add join
#        enrich step 23/32 calculate ownership field
#        enrich step 24/32 calculate county field
#        enrich step 25/32 calculate region field
#        enrich step 26/32 remove join
#          step has 661 records
#        enrich step 27/32 Calculating Years...
#        enrich step 28/32 Initiating Crosswalk...
#       Calculating Crosswalking Activites...
#           cross step 1/8 add join
#           cross step 2/8 calculate activities
#           cross step 3/8 calculate residue fate field
#           cross step 4/8 select attribute by layer
#           cross step 5/8 calculating objective...
#           cross step 6/8 calculate category
#       Calculate Activity Category Step 1/1
#           cross step 7/8 standardize domains
#           cross step 8/8 counts towards MAS
#       Calculating 'Counts to MAS'
#         counts step 1/8: set to 'NO'
#         counts step 2/8: select by bounding years (2020-2023)
#              this step is redundant and therefore skipped
#         counts step 3/8: set to 'YES' if activity description is in the list
#         counts step 3/8: set to 'NO' if not 'Acres'
#         counts step 4/8: set to 'NO' if status is 'Canceled', 'Planned', 'Outyear', or 'Proposed'
#         counts step 5/8: set to 'NO' if Activity Category is 'Watershed Improvement'
#         counts step 6/8: set to 'NO' if Agency is 'Other' and Admin is 'CARB'
#         counts step 7/8: set to 'NO' if Org is 'USFS' and Status is 'Active'
#         counts step 8/8: set to 'NO' if Admin is in the list
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#         field_list after: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#      Crosswalk Complete, Continuing Enrichment...
#          step has 661 records
# ----------------------------------------------------------------------
# check crosswalk_table
# The data type is FeatureLayer.
# Coordinate system: NAD_1983_California_Teale_Albers
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#        enrich step 29/32 Calculating Latitude and Longitude...
#        enrich step 30/32 calculate treatment acres
#        enrich step 31/32 removing unnecessary fields
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#         field_list after: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#          step has 661 records
#        enrich step 32/32
#          step has 661 records
#    Enrich Polygons Complete...
#      Enrichment Polygon script took: 0h, 2m, 5.0s to complete
#      enriched has 661 records
#    step 7/7 add project user ID
#       assigning domains
#    Polygon Enrichment Complete
# Deleting Scratch Files
# NFPORS polygon script took: 0h, 2m, 20.0s to complete
#        enrich step 28/32 Initiating Crosswalk...
#       Calculating Crosswalking Activites...
#           cross step 1/8 add join
#           cross step 2/8 calculate activities
#           cross step 3/8 calculate residue fate field
#           cross step 4/8 select attribute by layer
#           cross step 5/8 calculating objective...
#           cross step 6/8 calculate category
#       Calculate Activity Category Step 1/1
#           cross step 7/8 standardize domains
#           cross step 8/8 counts towards MAS
#       Calculating 'Counts to MAS'
#         counts step 1/8: set to 'NO'
#         counts step 2/8: select by bounding years (2020-2023)
#         counts step 3/8: set to 'YES' if activity description is in the list
#         counts step 3/8: set to 'NO' if not 'Acres'
#         counts step 4/8: set to 'NO' if status is 'Canceled', 'Planned', 'Outyear', or 'Proposed'
#         counts step 5/8: set to 'NO' if Activity Category is 'Watershed Improvement'
#         counts step 6/8: set to 'NO' if Agency is 'Other' and Admin is 'CARB'
#         counts step 7/8: set to 'NO' if Org is 'USFS' and Status is 'Active'
#         counts step 8/8: set to 'NO' if Admin is in the list
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#         field_list after: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#      Crosswalk Complete, Continuing Enrichment...
#          step has 2545 records
# ----------------------------------------------------------------------
# check crosswalk_table
# The data type is FeatureLayer.
# Coordinate system: NAD_1983_California_Teale_Albers
#         Fields: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#        enrich step 29/32 Calculating Latitude and Longitude...
#        enrich step 30/32 calculate treatment acres
#        enrich step 31/32 removing unnecessary fields
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#         field_list after: ['OBJECTID', 'Shape', 'projectid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#          step has 2545 records
#        enrich step 32/32
#          step has 2545 records
#    Enrich Polygons Complete...
#      Enrichment Polygon script took: 0h, 2m, 41.0s to complete
#      enriched has 2545 records
#    step 7/7 add project user ID
#       assigning domains
#    Polygon Enrichment Complete
# Deleting Scratch Files
# NFPORS polygon script took: 0h, 2m, 59.0s to complete

# %%
Model_NFPORS_point(
    input_original_pts_BIA, 
    input_original_pts_FWS, 
    output_pts_enriched
)
# Out:
# Points Standardization
#    step 1/6 select BIA points in CA
#      BIA Selected points has 117 records
#    step 2/6 select FWS points in CA
#      FWS Selected points has 68 records
#    step 3/6 combine points layers
#      appended points has 185 records
#    step 4/6 rename and add fields
#       assigning domains
#    step 5/6 import attributes
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'treatmentname', 'unitid', 'unitname', 'regionname', 'agencyname', 'deptname', 'countyname', 'statename', 'districtname', 'representative', 'keypointname', 'latitude_', 'longitude_', 'wuiid', 'plannedfy', 'initiatedfy', 'completedfy', 'plannedinitiationdate', 'actualinitiationdate', 'actualcompletiondate', 'categoryname', 'plannedaccomplishment', 'fyaccomplishment', 'totalaccomplishment', 'symbol', 'treatmentcreated', 'treatmentmodified', 'typename', 'source_', 'treatmentid', 'projectname', 'activitytreatapprvd', 'localapprvdt', 'regionalapprvdt', 'bureauapprvdt', 'unitofmeas', 'plancontrcost', 'plandirectcost', 'treatmentowner', 'nepatype', 'movedbetcondclassacres', 'regioncode', 'project_id', 'treatmentlocalidentifier', 'obligationfiscalyear', 'actualcompletionyear', 'activitytreatmentnotes', 'iswui', 'iscompleted', 'bureaurecguid', 'isbil', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#         field_list after: ['OBJECTID', 'shape', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
# Standardization Complete
#      standardized points has 185 records
#    Executing Point Enrichments...
#      Point Enrichment Start Time 2024-09-25 11:47:26.473920
#      Calculating WUI...
#        enrich step 1/16 select layer by WUI
#        enrich step 2/16 calculate WUI yes
#        enrich step 3/16 switch selection
#        enrich step 4/16 calculate WUI no
#        enrich step 5/16 clear selection
#      Calculating Ownership, Counties, and Regions...
#        enrich step 6/16 spatial join ownership
#        enrich step 7/16 spatial join regions
#        enrich step 8/16 spatial join veg
#        enrich step 9/16 calculate ownership
#        enrich step 10/16 calculate county
#        enrich step 11/16 calculate region
#        enrich step 12/16 calculate veg type
#        enrich step 13/16 Initiating Crosswalk
#       Calculating Crosswalking Activites...
#           cross step 1/8 add join
#           cross step 2/8 calculate activities
#           cross step 3/8 calculate residue fate field
#           cross step 4/8 select attribute by layer
#           cross step 5/8 calculating objective...
#           cross step 6/8 calculate category
#       Calculate Activity Category Step 1/1
#           cross step 7/8 standardize domains
#           cross step 8/8 counts towards MAS
#       Calculating 'Counts to MAS'
#         counts step 1/8: set to 'NO'
#         counts step 2/8: select by bounding years (2020-2023)
#              this step is redundant and therefore skipped
#         counts step 3/8: set to 'YES' if activity description is in the list
#         counts step 3/8: set to 'NO' if not 'Acres'
#         counts step 4/8: set to 'NO' if status is 'Canceled', 'Planned', 'Outyear', or 'Proposed'
#         counts step 5/8: set to 'NO' if Activity Category is 'Watershed Improvement'
#         counts step 6/8: set to 'NO' if Agency is 'Other' and Admin is 'CARB'
#         counts step 7/8: set to 'NO' if Org is 'USFS' and Status is 'Active'
#         counts step 8/8: set to 'NO' if Admin is in the list
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'Join_Count', 'TARGET_FID', 'Join_Count_1', 'TARGET_FID_1', 'Join_Count_12', 'TARGET_FID_12', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'AGNCY_LEV', 'COUNTY_1', 'GIS_ACRES', 'Region_1', 'GIS_Acres_1', 'Id', 'gridcode', 'WHR13NAME']
#         field_list after: ['OBJECTID', 'shape', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#      Crosswalk Complete, Continuing Enrichment
#        enrich step 14/16 Calculating Years
#        enrich step 15/16 Calculating Latitude and Longitude
#        enrich step 16/16 removing unnecessary fields
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#         field_list after: ['OBJECTID', 'shape', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#    Enrich Points Complete...
#      Enrichment Points script took: 0h, 7m, 13.0s to complete
#      enriched points has 185 records
#    step 6/6 add project user ID
#       assigning domains
# Point Enrichment Complete
# Deleting Scratch Files
# NFPORS point script took: 0h, 7m, 27.0s to complete
