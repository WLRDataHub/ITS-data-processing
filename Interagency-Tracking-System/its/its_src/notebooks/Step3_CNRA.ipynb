# %%
import sys
sys.path.append('../')

# %%
"""
# Description: Converts the California Department of Natural Resources' 
#              Fuels Treatments Tracker points, lines, and polygons datasets 
#              into the Task Force standardized schema.  Dataset
#              is enriched with vegetation, ownership, county, WUI, 
#              Task Force Region, and year.              
# Author: Spatial Informatics Group LLC
# Version: 1.0.0
# Date Created: Jan 24, 2024
"""
import os
import datetime
from scripts.utils import init_gdb, check_schema_lock
from scripts._3a_CNRA_Points import CNRA_pts_Model
from scripts._3a_CNRA_Lines import CNRA_lns_Model
from scripts._3a_CNRA_Polygons import CNRA_poly_Model

workspace, scratch_workspace = init_gdb()

date_id = datetime.datetime.now().strftime("%Y-%m-%d").replace("-", "")  # like 20221216

# INPUTS
# will need to be acquired from CNRA
# change path to the most updated inputs

project_path = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
data2023_path = os.path.join(project_path, "2023")

cnra_gdb = os.path.join(data2023_path, "CNRA_2023\CNRA_2023_20240619_fromReisThomasViaUpload.gdb")
input_pt_fc = os.path.join(cnra_gdb, "Treatment_Point")
input_ln_fc = os.path.join(cnra_gdb, "Treatment_Line")
input_poly_fc = os.path.join(cnra_gdb, "Treatment_Poly")
Activity_Table = os.path.join(cnra_gdb, "Activities")
Project_Poly= os.path.join(cnra_gdb, "Project_Poly")
WFR_TF_Template = os.path.join(workspace, "a_Reference", "WFR_TF_Template")

# OUTPUTS
# mpt (multipoint) | use if needed
# output_mpt_enriched = os.path.join(workspace, "c_Enriched", f"CNRA_enriched_mpt_{date_id}")
output_pt_enriched = os.path.join(workspace, "c_Enriched", f"CNRA_enriched_pt_{date_id}")
output_ln_enriched = os.path.join(workspace, "c_Enriched", f"CNRA_enriched_ln_{date_id}")
output_poly_enriched = os.path.join(workspace, "c_Enriched", f"CNRA_enriched_poly_{date_id}")

check_schema_lock(input_pt_fc)
check_schema_lock(input_ln_fc)
check_schema_lock(input_poly_fc)
check_schema_lock(Activity_Table)
check_schema_lock(Project_Poly)
# check_schema_lock(output_mpt_enriched)
check_schema_lock(output_pt_enriched)
check_schema_lock(output_ln_enriched)
check_schema_lock(output_poly_enriched)
# Out:
# Available for schema lock: D:\WORK\wildfire\Interagency-Tracking-System\2023\CNRA_2023\CNRA_2023_20240619_fromReisThomasViaUpload.gdb\Treatment_Point
# Available for schema lock: D:\WORK\wildfire\Interagency-Tracking-System\2023\CNRA_2023\CNRA_2023_20240619_fromReisThomasViaUpload.gdb\Treatment_Line
# Available for schema lock: D:\WORK\wildfire\Interagency-Tracking-System\2023\CNRA_2023\CNRA_2023_20240619_fromReisThomasViaUpload.gdb\Treatment_Poly
# Available for schema lock: D:\WORK\wildfire\Interagency-Tracking-System\2023\CNRA_2023\CNRA_2023_20240619_fromReisThomasViaUpload.gdb\Activities
# Available for schema lock: D:\WORK\wildfire\Interagency-Tracking-System\2023\CNRA_2023\CNRA_2023_20240619_fromReisThomasViaUpload.gdb\Project_Poly
# Dataset does not exist: D:\WORK\wildfire\Interagency-Tracking-System\its\Interagency Tracking System.gdb\c_Enriched\CNRA_enriched_pt_20240919
# Dataset does not exist: D:\WORK\wildfire\Interagency-Tracking-System\its\Interagency Tracking System.gdb\c_Enriched\CNRA_enriched_ln_20240919
# Dataset does not exist: D:\WORK\wildfire\Interagency-Tracking-System\its\Interagency Tracking System.gdb\c_Enriched\CNRA_enriched_poly_20240919

# %%
CNRA_poly_Model(
    input_poly_fc, 
    Activity_Table, 
    Project_Poly, 
    WFR_TF_Template, 
    output_poly_enriched
    )
# Out:
# Start Time 2024-09-19 14:22:17.911536
# Part 1 Prepare Features
# field PROJECTID_USER Exists: altering it to PROJECTID_USER_
# field TRMTID_USER Exists: altering it to TRMTID_USER_
# field PROJECTID Exists: altering it to PROJECTID_
# field PROJECTNAME_ Exists: altering it to PROJECTNAME__
# field ORG_ADMIN_t Exists: altering it to ORG_ADMIN_t_
# field PRIMARY_OWNERSHIP_GROUP Exists: altering it to PRIMARY_OWNERSHIP_GROUP_
# field PRIMARY_OBJECTIVE Exists: altering it to PRIMARY_OBJECTIVE_
# field SECONDARY_OBJECTIVE Exists: altering it to SECONDARY_OBJECTIVE_
# field TERTIARY_OBJECTIVE Exists: altering it to TERTIARY_OBJECTIVE_
# field TREATMENT_STATUS Exists: altering it to TREATMENT_STATUS_
# field COUNTY Exists: altering it to COUNTY_
# field IN_WUI Exists: altering it to IN_WUI_
# field REGION Exists: altering it to REGION_
# field TREATMENT_AREA Exists: altering it to TREATMENT_AREA_
# field TREATMENT_START Exists: altering it to TREATMENT_START_
# field TREATMENT_END Exists: altering it to TREATMENT_END_
# field RETREATMENT_DATE_EST Exists: altering it to RETREATMENT_DATE_EST_
# field TREATMENT_NAME Exists: altering it to TREATMENT_NAME_
#       assigning domains
#    step 1/17 edit ID's
# Part 2 Prepare Activity Table
#    step 2/17 remove miliseconds from dates
#    step 3/17 create standardized activity table
#    step 4/17 import activities
#      activities have 24130 records
#    step 5/17 calculate unique Treatment ID -CNRA
# Part 3 - Combine CNRA Features and Activity Table
#    step 6/17 join poly and table
#         join_1: ['CNRA_Treatment_Poly.OBJECTID', 'CNRA_Treatment_Poly.shape', 'CNRA_Treatment_Poly.globalid', 'CNRA_Treatment_Poly.PROJECTID_', 'CNRA_Treatment_Poly.TRMTID_USER_', 'CNRA_Treatment_Poly.PROJECTID_USER_', 'CNRA_Treatment_Poly.PROJECTNAME__', 'CNRA_Treatment_Poly.ORG_ADMIN_t_', 'CNRA_Treatment_Poly.PRIMARY_OWNERSHIP_GROUP_', 'CNRA_Treatment_Poly.PRIMARY_OBJECTIVE_', 'CNRA_Treatment_Poly.SECONDARY_OBJECTIVE_', 'CNRA_Treatment_Poly.TERTIARY_OBJECTIVE_', 'CNRA_Treatment_Poly.TREATMENT_STATUS_', 'CNRA_Treatment_Poly.COUNTY_', 'CNRA_Treatment_Poly.IN_WUI_', 'CNRA_Treatment_Poly.REGION_', 'CNRA_Treatment_Poly.TREATMENT_AREA_', 'CNRA_Treatment_Poly.TREATMENT_START_', 'CNRA_Treatment_Poly.TREATMENT_END_', 'CNRA_Treatment_Poly.RETREATMENT_DATE_EST_', 'CNRA_Treatment_Poly.TREATMENT_NAME_', 'CNRA_Treatment_Poly.globalid_text', 'CNRA_Treatment_Poly.created_user', 'CNRA_Treatment_Poly.created_date', 'CNRA_Treatment_Poly.last_edited_user', 'CNRA_Treatment_Poly.last_edited_date', 'CNRA_Treatment_Poly.validationstatus', 'CNRA_Treatment_Poly.shape_Length', 'CNRA_Treatment_Poly.shape_Area', 'CNRA_Treatment_Poly.PROJECTID_USER', 'CNRA_Treatment_Poly.AGENCY', 'CNRA_Treatment_Poly.ORG_ADMIN_p', 'CNRA_Treatment_Poly.PROJECT_CONTACT', 'CNRA_Treatment_Poly.PROJECT_EMAIL', 'CNRA_Treatment_Poly.ADMINISTERING_ORG', 'CNRA_Treatment_Poly.PROJECT_NAME', 'CNRA_Treatment_Poly.PROJECT_STATUS', 'CNRA_Treatment_Poly.PROJECT_START', 'CNRA_Treatment_Poly.PROJECT_END', 'CNRA_Treatment_Poly.PRIMARY_FUNDING_SOURCE', 'CNRA_Treatment_Poly.PRIMARY_FUNDING_ORG', 'CNRA_Treatment_Poly.IMPLEMENTING_ORG', 'CNRA_Treatment_Poly.LATITUDE', 'CNRA_Treatment_Poly.LONGITUDE', 'CNRA_Treatment_Poly.BatchID_p', 'CNRA_Treatment_Poly.Val_Status_p', 'CNRA_Treatment_Poly.Val_MSG_p', 'CNRA_Treatment_Poly.Val_RunDate_p', 'CNRA_Treatment_Poly.Review_Status_p', 'CNRA_Treatment_Poly.Review_MSG_p', 'CNRA_Treatment_Poly.Review_RunDate_p', 'CNRA_Treatment_Poly.Dataload_Status_p', 'CNRA_Treatment_Poly.Dataload_Msg_p', 'CNRA_Treatment_Poly.TRMTID_USER', 'CNRA_Treatment_Poly.PROJECTID', 'CNRA_Treatment_Poly.PROJECTNAME_', 'CNRA_Treatment_Poly.ORG_ADMIN_t', 'CNRA_Treatment_Poly.PRIMARY_OWNERSHIP_GROUP', 'CNRA_Treatment_Poly.PRIMARY_OBJECTIVE', 'CNRA_Treatment_Poly.SECONDARY_OBJECTIVE', 'CNRA_Treatment_Poly.TERTIARY_OBJECTIVE', 'CNRA_Treatment_Poly.TREATMENT_STATUS', 'CNRA_Treatment_Poly.COUNTY', 'CNRA_Treatment_Poly.IN_WUI', 'CNRA_Treatment_Poly.REGION', 'CNRA_Treatment_Poly.TREATMENT_AREA', 'CNRA_Treatment_Poly.TREATMENT_START', 'CNRA_Treatment_Poly.TREATMENT_END', 'CNRA_Treatment_Poly.RETREATMENT_DATE_EST', 'CNRA_Treatment_Poly.TREATMENT_NAME', 'CNRA_Treatment_Poly.BatchID', 'CNRA_Treatment_Poly.Val_Status_t', 'CNRA_Treatment_Poly.Val_MSG_t', 'CNRA_Treatment_Poly.Val_RunDate_t', 'CNRA_Treatment_Poly.Review_Status_t', 'CNRA_Treatment_Poly.Review_Msg_t', 'CNRA_Treatment_Poly.Review_RunDate_t', 'CNRA_Treatment_Poly.Dataload_Status_t', 'CNRA_Treatment_Poly.Dataload_Msg_t', 'CNRA_Treatment_Poly.ACTIVID_USER', 'CNRA_Treatment_Poly.TREATMENTID_', 'CNRA_Treatment_Poly.ORG_ADMIN_a', 'CNRA_Treatment_Poly.ACTIVITY_DESCRIPTION', 'CNRA_Treatment_Poly.ACTIVITY_CAT', 'CNRA_Treatment_Poly.BROAD_VEGETATION_TYPE', 'CNRA_Treatment_Poly.BVT_USERD', 'CNRA_Treatment_Poly.ACTIVITY_STATUS', 'CNRA_Treatment_Poly.ACTIVITY_QUANTITY', 'CNRA_Treatment_Poly.ACTIVITY_UOM', 'CNRA_Treatment_Poly.ACTIVITY_START', 'CNRA_Treatment_Poly.ACTIVITY_END', 'CNRA_Treatment_Poly.ADMIN_ORG_NAME', 'CNRA_Treatment_Poly.IMPLEM_ORG_NAME', 'CNRA_Treatment_Poly.PRIMARY_FUND_SRC_NAME', 'CNRA_Treatment_Poly.PRIMARY_FUND_ORG_NAME', 'CNRA_Treatment_Poly.SECONDARY_FUND_SRC_NAME', 'CNRA_Treatment_Poly.SECONDARY_FUND_ORG_NAME', 'CNRA_Treatment_Poly.TERTIARY_FUND_SRC_NAME', 'CNRA_Treatment_Poly.TERTIARY_FUND_ORG_NAME', 'CNRA_Treatment_Poly.ACTIVITY_PRCT', 'CNRA_Treatment_Poly.RESIDUE_FATE', 'CNRA_Treatment_Poly.RESIDUE_FATE_QUANTITY', 'CNRA_Treatment_Poly.RESIDUE_FATE_UNITS', 'CNRA_Treatment_Poly.ACTIVITY_NAME', 'CNRA_Treatment_Poly.VAL_STATU ...
# Part 4 Prepare Project Table
#    step 7/17 calculate unique Project ID if null
# Part 5 Join Project Table to Features/Activites
#    step 8/17 copy features
#    step 9/17 create Features
#         CNRA_Flat_2: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area']
#      CNRA_Flat_2 has 21894 records
#         standardized_1: ['OBJECTID', 'Shape', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_Msg_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_Msg_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_Msg_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'Shape_Length', 'Shape_Area']
#      standardized has 0 records
#    step 10/17 append
#      combined has 21894 records
#         append before: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area']
#         append_1: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area']
# Part 6 Standardize and Enrich
#    step 11/17 calc cross
#    step 12/17 calc source
#    step 13/17 calc admin
#    step 14/17 status
#    step 15/17 activity end date
# Export Final
#         field_list before: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area']
#    Executing Polygon Enrichments...
#      Polygon Enrichment Start Time 2024-09-19 14:22:17.911536
#      Calculating Broad Vegetation Type...
#        enrich step 1/32 summarize veg within polygons
#
#
# ==========> Number of features in Veg_Layer: 3736147
# -- enrich_in
# ==========> Number of features in enrich_in: 21894
#
#
#         Fields: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area']
#
# ---------- group table -------------
#         Fields: ['OBJECTID', 'Join_ID', 'WHR13NAME', 'sum_Area_ACRES', 'Polygon_Count']
#        enrich step 2/32 summarize attributes
#        OBJECTID  Join_ID          WHR13NAME  sum_Area_ACRES  Polygon_Count
# 0             1        1         Herbaceous        5.371617              4
# 1             2        1              Shrub        9.342552              1
# 2             3        1              Urban        3.975378              2
# 3             4        2              Urban        1.834863              1
# 4             5        3              Urban        6.668157              1
# ...         ...      ...                ...             ...            ...
# 76092     76093    21892              Shrub        0.210862              3
# 76093     76094    21893  Hardwood Woodland       20.600197              1
# 76094     76095    21893         Herbaceous        0.402803              1
# 76095     76096    21894  Hardwood Woodland        1.582907              1
# 76096     76097    21894              Urban        0.138278              1
#
# [76097 rows x 5 columns]
#
# ---------- grouped_df -------------
#        Join_ID  MAX_Sum_Area_ACRES  OBJECTID
# 0            1            9.342552         1
# 1            2            1.834863         2
# 2            3            6.668157         3
# 3            4           12.554245         4
# 4            5            2.720253         5
# ...        ...                 ...       ...
# 21889    21890            3.864870     21890
# 21890    21891            0.690210     21891
# 21891    21892           11.706916     21892
# 21892    21893           20.600197     21893
# 21893    21894            1.582907     21894
#
# [21894 rows x 3 columns]
#        enrich step 3/32 add join
#
# ----------- join_1 --------------
#         Fields: ['WHR13NAME_Summary_SummarizeAttributes.OBJECTID', 'WHR13NAME_Summary_SummarizeAttributes.Join_ID', 'WHR13NAME_Summary_SummarizeAttributes.MAX_Sum_Area_ACRES', 'WHR13NAME_Summary.OBJECTID', 'WHR13NAME_Summary.Join_ID', 'WHR13NAME_Summary.WHR13NAME', 'WHR13NAME_Summary.sum_Area_ACRES', 'WHR13NAME_Summary.Polygon_Count']
#          join_1 has 591560 records
#        enrich step 4/32 convert table to table
#
# ----------- sum_table --------------
#         Fields: ['OBJECTID_1', 'Join_ID', 'MAX_Sum_Area_ACRES', 'OBJECTID', 'Join_ID_1', 'WHR13NAME', 'sum_Area_ACRES', 'Polygon_Count']
#        enrich step 5/32 delete identical
#          step has 21894 records
#
# ----------- veg_sum --------------
#         Fields: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#          veg_sum has 21894 records
#
# ----------- delete_identical_1 --------------
#         Fields: ['OBJECTID_1', 'Join_ID', 'MAX_Sum_Area_ACRES', 'OBJECTID', 'Join_ID_1', 'WHR13NAME', 'sum_Area_ACRES', 'Polygon_Count']
#          delete_identical_1 has 21894 records
#        enrich step 6/32 add join
#
# ----------- join_2 --------------
#         Fields: ['Veg_Summarized_Polygons.OBJECTID', 'Veg_Summarized_Polygons.shape', 'Veg_Summarized_Polygons.globalid', 'Veg_Summarized_Polygons.PROJECTID_', 'Veg_Summarized_Polygons.TRMTID_USER_', 'Veg_Summarized_Polygons.PROJECTID_USER_', 'Veg_Summarized_Polygons.PROJECTNAME__', 'Veg_Summarized_Polygons.ORG_ADMIN_t_', 'Veg_Summarized_Polygons.PRIMARY_OWNERSHIP_GROUP_', 'Veg_Summarized_Polygons.PRIMARY_OBJECTIVE_', 'Veg_Summarized_Polygons.SECONDARY_OBJECTIVE_', 'Veg_Summarized_Polygons.TERTIARY_OBJECTIVE_', 'Veg_Summarized_Polygons.TREATMENT_STATUS_', 'Veg_Summarized_Polygons.COUNTY_', 'Veg_Summarized_Polygons.IN_WUI_', 'Veg_Summarized_Polygons.REGION_', 'Veg_Summarized_Polygons.TREATMENT_AREA_', 'Veg_Summarized_Polygons.TREATMENT_START_', 'Veg_Summarized_Polygons.TREATMENT_END_', 'Veg_Summarized_Polygons.RETREATMENT_DATE_EST_', 'Veg_Summarized_Polygons.TREATMENT_NAME_', 'Veg_Summarized_Polygons.globalid_text', 'Veg_Summarized_Polygons.created_user', 'Veg_Summarized_Polygons.created_date', 'Veg_Summarized_Polygons.last_edited_user', 'Veg_Summarized_Polygons.last_edited_date', 'Veg_Summarized_Polygons.validationstatus', 'Veg_Summarized_Polygons.PROJECTID_USER', 'Veg_Summarized_Polygons.AGENCY', 'Veg_Summarized_Polygons.ORG_ADMIN_p', 'Veg_Summarized_Polygons.PROJECT_CONTACT', 'Veg_Summarized_Polygons.PROJECT_EMAIL', 'Veg_Summarized_Polygons.ADMINISTERING_ORG', 'Veg_Summarized_Polygons.PROJECT_NAME', 'Veg_Summarized_Polygons.PROJECT_STATUS', 'Veg_Summarized_Polygons.PROJECT_START', 'Veg_Summarized_Polygons.PROJECT_END', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_SOURCE', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_ORG', 'Veg_Summarized_Polygons.IMPLEMENTING_ORG', 'Veg_Summarized_Polygons.LATITUDE', 'Veg_Summarized_Polygons.LONGITUDE', 'Veg_Summarized_Polygons.BatchID_p', 'Veg_Summarized_Polygons.Val_Status_p', 'Veg_Summarized_Polygons.Val_MSG_p', 'Veg_Summarized_Polygons.Val_RunDate_p', 'Veg_Summarized_Polygons.Review_Status_p', 'Veg_Summarized_Polygons.Review_MSG_p', 'Veg_Summarized_Polygons.Review_RunDate_p', 'Veg_Summarized_Polygons.Dataload_Status_p', 'Veg_Summarized_Polygons.Dataload_Msg_p', 'Veg_Summarized_Polygons.TRMTID_USER', 'Veg_Summarized_Polygons.PROJECTID', 'Veg_Summarized_Polygons.PROJECTNAME_', 'Veg_Summarized_Polygons.ORG_ADMIN_t', 'Veg_Summarized_Polygons.PRIMARY_OWNERSHIP_GROUP', 'Veg_Summarized_Polygons.PRIMARY_OBJECTIVE', 'Veg_Summarized_Polygons.SECONDARY_OBJECTIVE', 'Veg_Summarized_Polygons.TERTIARY_OBJECTIVE', 'Veg_Summarized_Polygons.TREATMENT_STATUS', 'Veg_Summarized_Polygons.COUNTY', 'Veg_Summarized_Polygons.IN_WUI', 'Veg_Summarized_Polygons.REGION', 'Veg_Summarized_Polygons.TREATMENT_AREA', 'Veg_Summarized_Polygons.TREATMENT_START', 'Veg_Summarized_Polygons.TREATMENT_END', 'Veg_Summarized_Polygons.RETREATMENT_DATE_EST', 'Veg_Summarized_Polygons.TREATMENT_NAME', 'Veg_Summarized_Polygons.BatchID', 'Veg_Summarized_Polygons.Val_Status_t', 'Veg_Summarized_Polygons.Val_MSG_t', 'Veg_Summarized_Polygons.Val_RunDate_t', 'Veg_Summarized_Polygons.Review_Status_t', 'Veg_Summarized_Polygons.Review_Msg_t', 'Veg_Summarized_Polygons.Review_RunDate_t', 'Veg_Summarized_Polygons.Dataload_Status_t', 'Veg_Summarized_Polygons.Dataload_Msg_t', 'Veg_Summarized_Polygons.ACTIVID_USER', 'Veg_Summarized_Polygons.TREATMENTID_', 'Veg_Summarized_Polygons.ORG_ADMIN_a', 'Veg_Summarized_Polygons.ACTIVITY_DESCRIPTION', 'Veg_Summarized_Polygons.ACTIVITY_CAT', 'Veg_Summarized_Polygons.BROAD_VEGETATION_TYPE', 'Veg_Summarized_Polygons.BVT_USERD', 'Veg_Summarized_Polygons.ACTIVITY_STATUS', 'Veg_Summarized_Polygons.ACTIVITY_QUANTITY', 'Veg_Summarized_Polygons.ACTIVITY_UOM', 'Veg_Summarized_Polygons.ACTIVITY_START', 'Veg_Summarized_Polygons.ACTIVITY_END', 'Veg_Summarized_Polygons.ADMIN_ORG_NAME', 'Veg_Summarized_Polygons.IMPLEM_ORG_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_ORG_NAME', 'Veg_Summ ...
#          join_2 has 21894 records
#        enrich step 7/32 select layer by attribute
#
# ----------- select_1 --------------
#         Fields: ['Veg_Summarized_Polygons.OBJECTID', 'Veg_Summarized_Polygons.shape', 'Veg_Summarized_Polygons.globalid', 'Veg_Summarized_Polygons.PROJECTID_', 'Veg_Summarized_Polygons.TRMTID_USER_', 'Veg_Summarized_Polygons.PROJECTID_USER_', 'Veg_Summarized_Polygons.PROJECTNAME__', 'Veg_Summarized_Polygons.ORG_ADMIN_t_', 'Veg_Summarized_Polygons.PRIMARY_OWNERSHIP_GROUP_', 'Veg_Summarized_Polygons.PRIMARY_OBJECTIVE_', 'Veg_Summarized_Polygons.SECONDARY_OBJECTIVE_', 'Veg_Summarized_Polygons.TERTIARY_OBJECTIVE_', 'Veg_Summarized_Polygons.TREATMENT_STATUS_', 'Veg_Summarized_Polygons.COUNTY_', 'Veg_Summarized_Polygons.IN_WUI_', 'Veg_Summarized_Polygons.REGION_', 'Veg_Summarized_Polygons.TREATMENT_AREA_', 'Veg_Summarized_Polygons.TREATMENT_START_', 'Veg_Summarized_Polygons.TREATMENT_END_', 'Veg_Summarized_Polygons.RETREATMENT_DATE_EST_', 'Veg_Summarized_Polygons.TREATMENT_NAME_', 'Veg_Summarized_Polygons.globalid_text', 'Veg_Summarized_Polygons.created_user', 'Veg_Summarized_Polygons.created_date', 'Veg_Summarized_Polygons.last_edited_user', 'Veg_Summarized_Polygons.last_edited_date', 'Veg_Summarized_Polygons.validationstatus', 'Veg_Summarized_Polygons.PROJECTID_USER', 'Veg_Summarized_Polygons.AGENCY', 'Veg_Summarized_Polygons.ORG_ADMIN_p', 'Veg_Summarized_Polygons.PROJECT_CONTACT', 'Veg_Summarized_Polygons.PROJECT_EMAIL', 'Veg_Summarized_Polygons.ADMINISTERING_ORG', 'Veg_Summarized_Polygons.PROJECT_NAME', 'Veg_Summarized_Polygons.PROJECT_STATUS', 'Veg_Summarized_Polygons.PROJECT_START', 'Veg_Summarized_Polygons.PROJECT_END', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_SOURCE', 'Veg_Summarized_Polygons.PRIMARY_FUNDING_ORG', 'Veg_Summarized_Polygons.IMPLEMENTING_ORG', 'Veg_Summarized_Polygons.LATITUDE', 'Veg_Summarized_Polygons.LONGITUDE', 'Veg_Summarized_Polygons.BatchID_p', 'Veg_Summarized_Polygons.Val_Status_p', 'Veg_Summarized_Polygons.Val_MSG_p', 'Veg_Summarized_Polygons.Val_RunDate_p', 'Veg_Summarized_Polygons.Review_Status_p', 'Veg_Summarized_Polygons.Review_MSG_p', 'Veg_Summarized_Polygons.Review_RunDate_p', 'Veg_Summarized_Polygons.Dataload_Status_p', 'Veg_Summarized_Polygons.Dataload_Msg_p', 'Veg_Summarized_Polygons.TRMTID_USER', 'Veg_Summarized_Polygons.PROJECTID', 'Veg_Summarized_Polygons.PROJECTNAME_', 'Veg_Summarized_Polygons.ORG_ADMIN_t', 'Veg_Summarized_Polygons.PRIMARY_OWNERSHIP_GROUP', 'Veg_Summarized_Polygons.PRIMARY_OBJECTIVE', 'Veg_Summarized_Polygons.SECONDARY_OBJECTIVE', 'Veg_Summarized_Polygons.TERTIARY_OBJECTIVE', 'Veg_Summarized_Polygons.TREATMENT_STATUS', 'Veg_Summarized_Polygons.COUNTY', 'Veg_Summarized_Polygons.IN_WUI', 'Veg_Summarized_Polygons.REGION', 'Veg_Summarized_Polygons.TREATMENT_AREA', 'Veg_Summarized_Polygons.TREATMENT_START', 'Veg_Summarized_Polygons.TREATMENT_END', 'Veg_Summarized_Polygons.RETREATMENT_DATE_EST', 'Veg_Summarized_Polygons.TREATMENT_NAME', 'Veg_Summarized_Polygons.BatchID', 'Veg_Summarized_Polygons.Val_Status_t', 'Veg_Summarized_Polygons.Val_MSG_t', 'Veg_Summarized_Polygons.Val_RunDate_t', 'Veg_Summarized_Polygons.Review_Status_t', 'Veg_Summarized_Polygons.Review_Msg_t', 'Veg_Summarized_Polygons.Review_RunDate_t', 'Veg_Summarized_Polygons.Dataload_Status_t', 'Veg_Summarized_Polygons.Dataload_Msg_t', 'Veg_Summarized_Polygons.ACTIVID_USER', 'Veg_Summarized_Polygons.TREATMENTID_', 'Veg_Summarized_Polygons.ORG_ADMIN_a', 'Veg_Summarized_Polygons.ACTIVITY_DESCRIPTION', 'Veg_Summarized_Polygons.ACTIVITY_CAT', 'Veg_Summarized_Polygons.BROAD_VEGETATION_TYPE', 'Veg_Summarized_Polygons.BVT_USERD', 'Veg_Summarized_Polygons.ACTIVITY_STATUS', 'Veg_Summarized_Polygons.ACTIVITY_QUANTITY', 'Veg_Summarized_Polygons.ACTIVITY_UOM', 'Veg_Summarized_Polygons.ACTIVITY_START', 'Veg_Summarized_Polygons.ACTIVITY_END', 'Veg_Summarized_Polygons.ADMIN_ORG_NAME', 'Veg_Summarized_Polygons.IMPLEM_ORG_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.PRIMARY_FUND_ORG_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_SRC_NAME', 'Veg_Summarized_Polygons.SECONDARY_FUND_ORG_NAME', 'Veg_Summ ...
#          select_1 has 0 records
#          select_1 has 0 records
#        enrich step 8/32 calculate user defined veg field yes
#        enrich step 9/32 select layer by attribute
#        enrich step 10/32 calculate veg domain code
#        enrich step 11/32 calculate user defined veg field no
#        enrich step 12/32 remove join
#          step has 21894 records
#
# ----------- remove_join_1 --------------
#         Fields: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#      Calculating WUI...
#        enrich step 13/32 select layer by attribute
#        enrich step 14/32 select layer by WUI location
#        enrich step 15/32 calculate WUI yes
#
# ----------- calc_field_4 --------------
#         Fields: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#        enrich step 16/32 select layer by attribute
#        enrich step 17/32 calculate WUI no
#        enrich step 18/32 clear selection
#
# ----------- select_7 --------------
# ...
#      Calculating Ownership, Counties, and Regions...
#        enrich step 20/32 spatial join ownership
#        enrich step 21/32 spatial join veg
#        enrich step 22/32 add join
#        enrich step 23/32 calculate ownership field
#        enrich step 24/32 calculate county field
#        enrich step 25/32 calculate region field
#        enrich step 26/32 remove join
#          step has 21894 records
#        enrich step 27/32 Calculating Years...
#        enrich step 28/32 Initiating Crosswalk...
#       Calculating Crosswalking Activites...
#           cross step 1/8 add join
#           cross step 2/8 calculate activities
#           cross step 3/8 calculate residue fate field
#           cross step 4/8 select attribute by layer
#           cross step 5/8 calculating objective...
#           cross step 6/8 calculate category
#       Calculate Activity Category Step 1/1
#           cross step 7/8 standardize domains
#           cross step 8/8 counts towards MAS
#       Calculating 'Counts to MAS'
#         counts step 1/8: set to 'NO'
#         counts step 2/8: select by bounding years (2020-2023)
#              this step is redundant and therefore skipped
#         counts step 3/8: set to 'YES' if activity description is in the list
#         counts step 3/8: set to 'NO' if not 'Acres'
#         counts step 4/8: set to 'NO' if status is 'Canceled', 'Planned', 'Outyear', or 'Proposed'
#         counts step 5/8: set to 'NO' if Activity Category is 'Watershed Improvement'
#         counts step 6/8: set to 'NO' if Agency is 'Other' and Admin is 'CARB'
#         counts step 7/8: set to 'NO' if Org is 'USFS' and Status is 'Active'
#         counts step 8/8: set to 'NO' if Admin is in the list
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid_text', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'shape_Length', 'shape_Area', 'sum_Area_ACRES', 'Polygon_Count', 'Join_ID']
#         field_list after: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'shape_Length', 'shape_Area']
#      Crosswalk Complete, Continuing Enrichment...
#          step has 21894 records
# ----------------------------------------------------------------------
# check crosswalk_table
# The data type is FeatureLayer.
# Coordinate system: NAD_1983_California_Teale_Albers
#         Fields: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'shape_Length', 'shape_Area']
#        enrich step 29/32 Calculating Latitude and Longitude...
#        enrich step 30/32 calculate treatment acres
#        enrich step 31/32 removing unnecessary fields
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'shape_Length', 'shape_Area']
#         field_list after: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'shape_Length', 'shape_Area']
#          step has 21894 records
#        enrich step 32/32
#          step has 21894 records
#    Enrich Polygons Complete...
#      Enrichment Polygon script took: 0h, 15m, 13.0s to complete
# Enrichment Complete
#      enriched has 21894 records
# Export Final
#      final has 21894 records
#    step 17/17 assign domains
#       assigning domains
# CNRA Poly script took: 0h, 15m, 29.0s to complete
# 'D:\\WORK\\wildfire\\Interagency-Tracking-System\\its\\Interagency Tracking System.gdb\\c_Enriched\\CNRA_enriched_poly_20240919'

# %%
from scripts.utils import delete_scratch_files

# %%
delete_scratch_files(
    gdb=scratch_workspace, 
    delete_fc="yes", 
    delete_table="yes", 
    delete_ds="yes"
)

# %%
CNRA_lns_Model(
    input_ln_fc, 
    Activity_Table, 
    Project_Poly, 
    WFR_TF_Template, 
    output_ln_enriched
    )
# Out:
# Start Time 2024-09-19 14:22:17.904539
# Part 1 Prepare Features
# field PROJECTID_USER Exists: altering it to PROJECTID_USER_
# field TRMTID_USER Exists: altering it to TRMTID_USER_
# field PROJECTID Exists: altering it to PROJECTID_
# field PROJECTNAME_ Exists: altering it to PROJECTNAME__
# field ORG_ADMIN_t Exists: altering it to ORG_ADMIN_t_
# field PRIMARY_OWNERSHIP_GROUP Exists: altering it to PRIMARY_OWNERSHIP_GROUP_
# field PRIMARY_OBJECTIVE Exists: altering it to PRIMARY_OBJECTIVE_
# field SECONDARY_OBJECTIVE Exists: altering it to SECONDARY_OBJECTIVE_
# field TERTIARY_OBJECTIVE Exists: altering it to TERTIARY_OBJECTIVE_
# field TREATMENT_STATUS Exists: altering it to TREATMENT_STATUS_
# field COUNTY Exists: altering it to COUNTY_
# field IN_WUI Exists: altering it to IN_WUI_
# field REGION Exists: altering it to REGION_
# field TREATMENT_AREA Exists: altering it to TREATMENT_AREA_
# field TREATMENT_START Exists: altering it to TREATMENT_START_
# field TREATMENT_END Exists: altering it to TREATMENT_END_
# field RETREATMENT_DATE_EST Exists: altering it to RETREATMENT_DATE_EST_
# field TREATMENT_NAME Exists: altering it to TREATMENT_NAME_
#       assigning domains
#    step 1/17 edit ID's
# Part 2 Prepare Activity Table
#    step 2/17 remove miliseconds from dates
#    step 3/17 create standardized activity table
#    step 4/17 import activities
#      activities have 24130 records
#    step 5/17 calculate unique Treatment ID -CNRA
# Part 3 - Combine CNRA Features and Activity Table
#    step 6/17 join lines and table
# Part 4 Prepare Project Table
#    step 7/17 calculate unique Project ID if null
# Part 5 Join Project Table to Features/Activites
#    step 8/17 copy features
#    step 9/17 create Features
#    step 10/17 append
#      standardized has 290 records
# Part 6 Standardize and Enrich
#    step 11/17 calc cross
#    step 12/17 calc source
#    step 13/17 calc admin
#    step 14/17 status
#    step 15/17 activity end date
#    Executing Line Enrichments...
#      Line Enrichment Start Time 2024-09-19 14:22:17.904539
#        enrich step 1/4 convert to points
#        enrich step 2/4 execute enrich_points...
#    Executing Point Enrichments...
#      Point Enrichment Start Time 2024-09-19 14:22:17.894537
#      Calculating WUI...
#        enrich step 1/16 select layer by WUI
#        enrich step 2/16 calculate WUI yes
#        enrich step 3/16 switch selection
#        enrich step 4/16 calculate WUI no
#        enrich step 5/16 clear selection
#      Calculating Ownership, Counties, and Regions...
#        enrich step 6/16 spatial join ownership
#        enrich step 7/16 spatial join regions
#        enrich step 8/16 spatial join veg
#        enrich step 9/16 calculate ownership
#        enrich step 10/16 calculate county
#        enrich step 11/16 calculate region
#        enrich step 12/16 calculate veg type
#        enrich step 13/16 Initiating Crosswalk
#       Calculating Crosswalking Activites...
#           cross step 1/8 add join
#           cross step 2/8 calculate activities
#           cross step 3/8 calculate residue fate field
#           cross step 4/8 select attribute by layer
#           cross step 5/8 calculating objective...
#           cross step 6/8 calculate category
#       Calculate Activity Category Step 1/1
#           cross step 7/8 standardize domains
#           cross step 8/8 counts towards MAS
#       Calculating 'Counts to MAS'
#         counts step 1/8: set to 'NO'
#         counts step 2/8: select by bounding years (2020-2023)
#              this step is redundant and therefore skipped
#         counts step 3/8: set to 'YES' if activity description is in the list
#         counts step 3/8: set to 'NO' if not 'Acres'
#         counts step 4/8: set to 'NO' if status is 'Canceled', 'Planned', 'Outyear', or 'Proposed'
#         counts step 5/8: set to 'NO' if Activity Category is 'Watershed Improvement'
#         counts step 6/8: set to 'NO' if Agency is 'Other' and Admin is 'CARB'
#         counts step 7/8: set to 'NO' if Org is 'USFS' and Status is 'Active'
#         counts step 8/8: set to 'NO' if Admin is in the list
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'Join_Count', 'TARGET_FID', 'Join_Count_1', 'TARGET_FID_1', 'Join_Count_12', 'TARGET_FID_12', 'TRMTID_USER_', 'PROJECTID_USER_', 'PROJECTNAME__', 'ORG_ADMIN_t_', 'PRIMARY_OWNERSHIP_GROUP_', 'PRIMARY_OBJECTIVE_', 'SECONDARY_OBJECTIVE_', 'TERTIARY_OBJECTIVE_', 'TREATMENT_STATUS_', 'COUNTY_', 'IN_WUI_', 'REGION_', 'TREATMENT_AREA_', 'TREATMENT_START_', 'TREATMENT_END_', 'RETREATMENT_DATE_EST_', 'TREATMENT_NAME_', 'globalid', 'globalid_text', 'PROJECTID_', 'created_user', 'created_date', 'last_edited_user', 'last_edited_date', 'validationstatus', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS', 'OBJECTID_1', 'ACTIVID_USER_1', 'TREATMENTID1', 'ORG_ADMIN_a_1', 'ACTIVITY_DESCRIPTION_1', 'ACTIVITY_CAT_1', 'BROAD_VEGETATION_TYPE_1', 'BVT_USERD_1', 'ACTIVITY_STATUS_1', 'ACTIVITY_QUANTITY_1', 'ACTIVITY_UOM_1', 'ACTIVITY_START_1', 'ACTIVITY_END_1', 'ADMIN_ORG_NAME_1', 'IMPLEM_ORG_NAME_1', 'PRIMARY_FUND_SRC_NAME_1', 'PRIMARY_FUND_ORG_NAME_1', 'SECONDARY_FUND_SRC_NAME_1', 'SECONDARY_FUND_ORG_NAME_1', 'TERTIARY_FUND_SRC_NAME_1', 'TERTIARY_FUND_ORG_NAME_1', 'ACTIVITY_PRCT_1', 'RESIDUE_FATE_1', 'RESIDUE_FATE_QUANTITY_1', 'RESIDUE_FATE_UNITS_1', 'ACTIVITY_NAME_1', 'VAL_STATUS_a_1', 'VAL_MSG_a_1', 'VAL_RUNDATE_a_1', 'REVIEW_STATUS_a_1', 'REVIEW_MSG_a_1', 'REVIEW_RUNDATE_a_1', 'DATALOAD_STATUS_a_1', 'DATALOAD_MSG_a_1', 'Source_1', 'Year_1', 'Year_txt_1', 'Act_Code_1', 'Crosswalk_1', 'Federal_FY_1', 'State_FY_1', 'TRMTID_USER_1', 'BATCHID_a', 'TRMT_GEOM_1', 'COUNTS_TO_MAS_1', 'OBJECTID_12', 'globalid_1', 'projectid_user_1', 'agency_1', 'org_admin_p_1', 'project_contact_1', 'project_email_1', 'administering_org_1', 'project_name_1', 'project_status_1', 'project_start_1', 'project_end_1', 'primary_funding_source_1', 'primary_funding_org_1', 'implementing_org_1', 'latitude_1', 'longitude_1', 'globalid_text_1', 'created_user_1', 'created_date_1', 'last_edited_user_1', 'last_edited_date_1', 'validationstatus_1', 'ORIG_FID', 'AGNCY_LEV', 'COUNTY_1', 'GIS_ACRES', 'Region_1', 'GIS_Acres_1', 'Id', 'gridcode', 'WHR13NAME']
#         field_list after: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#      Crosswalk Complete, Continuing Enrichment
#        enrich step 14/16 Calculating Years
#        enrich step 15/16 Calculating Latitude and Longitude
#        enrich step 16/16 removing unnecessary fields
#           removing unnecessary fields
#         field_list before: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#         field_list after: ['OBJECTID', 'shape', 'globalid', 'PROJECTID_USER', 'AGENCY', 'ORG_ADMIN_p', 'PROJECT_CONTACT', 'PROJECT_EMAIL', 'ADMINISTERING_ORG', 'PROJECT_NAME', 'PROJECT_STATUS', 'PROJECT_START', 'PROJECT_END', 'PRIMARY_FUNDING_SOURCE', 'PRIMARY_FUNDING_ORG', 'IMPLEMENTING_ORG', 'LATITUDE', 'LONGITUDE', 'BatchID_p', 'Val_Status_p', 'Val_MSG_p', 'Val_RunDate_p', 'Review_Status_p', 'Review_MSG_p', 'Review_RunDate_p', 'Dataload_Status_p', 'Dataload_Msg_p', 'TRMTID_USER', 'PROJECTID', 'PROJECTNAME_', 'ORG_ADMIN_t', 'PRIMARY_OWNERSHIP_GROUP', 'PRIMARY_OBJECTIVE', 'SECONDARY_OBJECTIVE', 'TERTIARY_OBJECTIVE', 'TREATMENT_STATUS', 'COUNTY', 'IN_WUI', 'REGION', 'TREATMENT_AREA', 'TREATMENT_START', 'TREATMENT_END', 'RETREATMENT_DATE_EST', 'TREATMENT_NAME', 'BatchID', 'Val_Status_t', 'Val_MSG_t', 'Val_RunDate_t', 'Review_Status_t', 'Review_Msg_t', 'Review_RunDate_t', 'Dataload_Status_t', 'Dataload_Msg_t', 'ACTIVID_USER', 'TREATMENTID_', 'ORG_ADMIN_a', 'ACTIVITY_DESCRIPTION', 'ACTIVITY_CAT', 'BROAD_VEGETATION_TYPE', 'BVT_USERD', 'ACTIVITY_STATUS', 'ACTIVITY_QUANTITY', 'ACTIVITY_UOM', 'ACTIVITY_START', 'ACTIVITY_END', 'ADMIN_ORG_NAME', 'IMPLEM_ORG_NAME', 'PRIMARY_FUND_SRC_NAME', 'PRIMARY_FUND_ORG_NAME', 'SECONDARY_FUND_SRC_NAME', 'SECONDARY_FUND_ORG_NAME', 'TERTIARY_FUND_SRC_NAME', 'TERTIARY_FUND_ORG_NAME', 'ACTIVITY_PRCT', 'RESIDUE_FATE', 'RESIDUE_FATE_QUANTITY', 'RESIDUE_FATE_UNITS', 'ACTIVITY_NAME', 'VAL_STATUS_a', 'VAL_MSG_a', 'VAL_RUNDATE_a', 'REVIEW_STATUS_a', 'REVIEW_MSG_a', 'REVIEW_RUNDATE_a', 'DATALOAD_STATUS_a', 'DATALOAD_MSG_a', 'Source', 'Year', 'Year_txt', 'Act_Code', 'Crosswalk', 'Federal_FY', 'State_FY', 'TRMT_GEOM', 'COUNTS_TO_MAS']
#    Enrich Points Complete...
#      Enrichment Points script took: 1h, 18m, 55.0s to complete
#        enrich step 3/4 importing attributes
#        enrich step 4/4 align to template
#    Enrich Lines Complete...
#      Enrichment Lines script took: 1h, 19m, 1.0s to complete
# Enrichment Complete
#      enriched has 290 records
# Export Final
#      final has 290 records
#    step 17/17 assign domains
#       assigning domains
# Deleting Scratch Files
# CNRA Lines script took: 1h, 19m, 22.0s to complete
# 'D:\\WORK\\wildfire\\Interagency-Tracking-System\\its\\Interagency Tracking System.gdb\\c_Enriched\\CNRA_enriched_ln_20240919'

# %%
CNRA_pts_Model(
    input_pt_fc, 
    Activity_Table, 
    Project_Poly, 
    WFR_TF_Template, 
    output_pt_enriched
    )
# multi_pt_to_pt = arcpy.management.FeatureToPoint(output_mpt_enriched, output_pt_enriched, "INSIDE")
# Out:
# Start Time 2024-09-19 14:22:17.884181
# Part 1 Prepare Features
# field PROJECTID_USER Exists: altering it to PROJECTID_USER_
# field TRMTID_USER Exists: altering it to TRMTID_USER_
# field PROJECTID Exists: altering it to PROJECTID_
# field PROJECTNAME_ Exists: altering it to PROJECTNAME__
# field ORG_ADMIN_t Exists: altering it to ORG_ADMIN_t_
# field PRIMARY_OWNERSHIP_GROUP Exists: altering it to PRIMARY_OWNERSHIP_GROUP_
# field PRIMARY_OBJECTIVE Exists: altering it to PRIMARY_OBJECTIVE_
# field SECONDARY_OBJECTIVE Exists: altering it to SECONDARY_OBJECTIVE_
# field TERTIARY_OBJECTIVE Exists: altering it to TERTIARY_OBJECTIVE_
# field TREATMENT_STATUS Exists: altering it to TREATMENT_STATUS_
# field COUNTY Exists: altering it to COUNTY_
# field IN_WUI Exists: altering it to IN_WUI_
# field REGION Exists: altering it to REGION_
# field TREATMENT_AREA Exists: altering it to TREATMENT_AREA_
# field TREATMENT_START Exists: altering it to TREATMENT_START_
# field TREATMENT_END Exists: altering it to TREATMENT_END_
# field RETREATMENT_DATE_EST Exists: altering it to RETREATMENT_DATE_EST_
# field TREATMENT_NAME Exists: altering it to TREATMENT_NAME_
#       assigning domains
#    step 1/17 edit ID's
# Part 2 Prepare Activity Table
#    step 2/17 remove miliseconds from dates
#    step 3/17 create standardized activity table
#    step 4/17 import activities
#      activities have 24130 records
#    step 5/17 calculate unique Treatment ID -CNRA
# Part 3 - Combine CNRA Features and Activity Table
#    step 6/17 join points and table
# Part 4 Prepare Project Table
#    step 7/17 calculate unique Project ID if null
# Part 5 Join Project Table to Features/Activites
#    step 8/17 copy features
#    step 9/17 create Features
# ======> cnra_flat_2_geom_type: Point
# ======> standardized_geom_type: Point
#    step 10/17 append
#      standardized has 3227 records
# Part 6 Standardize and Enrich
#    step 11/17 calc cross
#    step 12/17 calc source
#    step 13/17 calc admin
#    step 14/17 status
#    step 15/17 activity end date
#    Executing Point Enrichments...
#      Point Enrichment Start Time 2024-09-19 14:22:17.894537
#      Calculating WUI...
#        enrich step 1/16 select layer by WUI
#        enrich step 2/16 calculate WUI yes
#        enrich step 3/16 switch selection
#        enrich step 4/16 calculate WUI no
#        enrich step 5/16 clear selection
#      Calculating Ownership, Counties, and Regions...
#        enrich step 6/16 spatial join ownership
#        enrich step 7/16 spatial join regions
#        enrich step 8/16 spatial join veg
